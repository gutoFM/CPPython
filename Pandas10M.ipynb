# %% [markdown]
# # Augusto Fisco Milreu - RM98245 - 2ESPF

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 10 Minutos Pandas

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
print (s)
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20130101", periods=6)
print (dates)

print("-------------------------------------------------")

df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))

df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)


print(df)
print("-------------------------------------------------")
print(df2)
print("-------------------------------------------------")
print(df2.dtypes)

print(df2.to_numpy())

print(df.head())
print("-------------------------------------------------")
print(df.tail(3))
print("-------------------------------------------------")
print(df.index)
print("-------------------------------------------------")
print(df.columns)
print("-------------------------------------------------")
print(df.to_numpy())
print("-------------------------------------------------")
print(df.describe())
print("-------------------------------------------------")
print(df.T)
print("-------------------------------------------------")
print(df.sort_index(axis=1, ascending=False))
print("-------------------------------------------------")
print(df.sort_values(by="B"))
print("-------------------------------------------------")
print(df["A"])
print("-------------------------------------------------")
print(df[0:3])
print("-------------------------------------------------")
print(df["20130102":"20130104"])
print("-------------------------------------------------")
print(df.loc[dates[0]])
print("-------------------------------------------------")
print(df.loc[:, ["A", "B"]])
print("-------------------------------------------------")
print(df.loc["20130102":"20130104", ["A", "B"]])
print("-------------------------------------------------")
print(df.loc[dates[0], "A"])
print("-------------------------------------------------")
print(df.at[dates[0], "A"])
print("-------------------------------------------------")
print(df.iloc[3])
print("-------------------------------------------------")
print(df.iloc[3:5, 0:2])
print("-------------------------------------------------")
print(df.iloc[[1, 2, 4], [0, 2]])
print("-------------------------------------------------")
print(df.iloc[1:3, :])
print("-------------------------------------------------")
print(df.iloc[:, 1:3])
print("-------------------------------------------------")
print(df.iloc[1, 1])
print("-------------------------------------------------")
print(df.iat[1, 1])
print("-------------------------------------------------")
print(df[df["A"] > 0])
print("-------------------------------------------------")
print(df[df > 0])
print("-------------------------------------------------")
df2 = df.copy()

df2["E"] = ["one", "one", "two", "three", "four", "three"]

print(df2)
print("-------------------------------------------------")
print(df2[df2["E"].isin(["two", "four"])])
print("-------------------------------------------------")

s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range("20130102", periods=6))

print("-------------------------------------------------")
print(s1)
print("-------------------------------------------------")

df["F"] = s1

df.at[dates[0], "A"] = 0

df.iat[0, 1] = 0

df.loc[:, "D"] = np.array([5] * len(df))

print("-------------------------------------------------")
print(df)
print("-------------------------------------------------")

df2 = df.copy()

df2[df2 > 0] = -df2

print("-------------------------------------------------")
print(df2)
print("-------------------------------------------------")

df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])

df1.loc[dates[0] : dates[1], "E"] = 1

print("-------------------------------------------------")
print(df1)
print("-------------------------------------------------")
print(df1.dropna(how="any"))
print("-------------------------------------------------")
print(df1.fillna(value=5))
print("-------------------------------------------------")
print(pd.isna(df1))
print("-------------------------------------------------")
print(df.mean())
print("-------------------------------------------------")
print(df.mean(axis=1))
print("-------------------------------------------------")

s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)

print("-------------------------------------------------")
print(s)
print("-------------------------------------------------")
print(df.sub(s, axis="index"))
print("-------------------------------------------------")
print(df.agg(lambda x: np.mean(x) * 5.6))
print("-------------------------------------------------")
print(df.transform(lambda x: x * 101.2))
print("-------------------------------------------------")

s = pd.Series(np.random.randint(0, 7, size=10))

print("-------------------------------------------------")
print(s)
print("-------------------------------------------------")
print(s.value_counts())
print("-------------------------------------------------")

s = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])

print("-------------------------------------------------")
print(s.str.lower())
print("-------------------------------------------------")

df = pd.DataFrame(np.random.randn(10, 4))

print("-------------------------------------------------")
print(df)
print("-------------------------------------------------")

pieces = [df[:3], df[3:7], df[7:]]

print("-------------------------------------------------")
print(pd.concat(pieces))
print("-------------------------------------------------")

left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})

right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4, 5]})

print("-------------------------------------------------")
print(left)
print("-------------------------------------------------")
print(right)
print("-------------------------------------------------")
print(pd.merge(left, right, on="key"))
print("-------------------------------------------------")

left = pd.DataFrame({"key": ["foo", "bar"], "lval": [1, 2]})

right = pd.DataFrame({"key": ["foo", "bar"], "rval": [4, 5]})

print("-------------------------------------------------")
print(left)
print("-------------------------------------------------")
print(right)
print("-------------------------------------------------")
print(pd.merge(left, right, on="key"))
print("-------------------------------------------------")

df = pd.DataFrame(
    {
        "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
        "B": ["one", "one", "two", "three", "two", "two", "one", "three"],
        "C": np.random.randn(8),
        "D": np.random.randn(8),
    }
)

print("-------------------------------------------------")
print(df)
print("-------------------------------------------------")
print(df.groupby("A")[["C", "D"]].sum())
print("-------------------------------------------------")
print(df.groupby(["A", "B"]).sum())
print("-------------------------------------------------")

arrays = [
   ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
   ["one", "two", "one", "two", "one", "two", "one", "two"],
]

index = pd.MultiIndex.from_arrays(arrays, names=["first", "second"])

df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=["A", "B"])

df2 = df[:4]

print("-------------------------------------------------")
print(df2)
print("-------------------------------------------------")

df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)

print("-------------------------------------------------")
print(df)
print("-------------------------------------------------")
print(pd.pivot_table(df, values="D", index=["A", "B"], columns=["C"]))
print("-------------------------------------------------")

rng = pd.date_range("1/1/2012", periods=100, freq="s")

ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

print("-------------------------------------------------")
print(ts.resample("5Min").sum())
print("-------------------------------------------------")

rng = pd.date_range("3/6/2012 00:00", periods=5, freq="D")

ts = pd.Series(np.random.randn(len(rng)), rng)

print("-------------------------------------------------")
print(ts)
print("-------------------------------------------------")

ts_utc = ts.tz_localize("UTC")

print("-------------------------------------------------")
print(ts_utc)
print("-------------------------------------------------")
print(ts_utc.tz_convert("US/Eastern"))
print("-------------------------------------------------")
print(rng)
print("-------------------------------------------------")
print(rng + pd.offsets.BusinessDay(5))
print("-------------------------------------------------")

df = pd.DataFrame(
    {"id": [1, 2, 3, 4, 5, 6], "raw_grade": ["a", "b", "b", "a", "a", "e"]}
)

df["grade"] = df["raw_grade"].astype("category")

print("-------------------------------------------------")
print(df["grade"])
print("-------------------------------------------------")

new_categories = ["very good", "good", "very bad"]

df["grade"] = df["grade"].cat.rename_categories(new_categories)

df["grade"] = df["grade"].cat.set_categories(
    ["very bad", "bad", "medium", "good", "very good"]
)

print("-------------------------------------------------")
print(df["grade"])
print("-------------------------------------------------")
print(df.sort_values(by="grade"))
print("-------------------------------------------------")
print(df.groupby("grade", observed=False).size())
print("-------------------------------------------------")

plt.close("all")

ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))

ts = ts.cumsum()

ts.plot();

df = pd.DataFrame(
    np.random.randn(1000, 4), index=ts.index, columns=["A", "B", "C", "D"]
)

df = df.cumsum()

plt.figure();

df.plot();

plt.legend(loc='best');

df = pd.DataFrame(np.random.randint(0, 5, (10, 5)))

df.to_csv("foo.csv")

print("-------------------------------------------------")
print(pd.read_csv("foo.csv"))
print("-------------------------------------------------")

df.to_parquet("foo.parquet")

print("-------------------------------------------------")
print(pd.read_parquet("foo.parquet"))
print("-------------------------------------------------")

df.to_excel("foo.xlsx", sheet_name="Sheet1")


print(pd.read_excel("foo.xlsx", "Sheet1", index_col=None, na_values=["NA"]))
print("-------------------------------------------------")
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')
# -------------------------------------------------
#                    A         B         C         D
# 2013-01-01  0.231297  0.712790 -0.814281 -1.027549
# 2013-01-02  0.692430 -2.029240 -1.029616 -0.128162
# 2013-01-03  0.794290  1.833174  0.090310 -0.504759
# 2013-01-04 -0.236760  1.369424  0.783792 -1.045383
# 2013-01-05  0.171231 -0.245067 -0.540469 -0.743894
# 2013-01-06  0.060644 -1.325892  0.118875 -0.639578
# -------------------------------------------------
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo
# -------------------------------------------------
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object
# [[1.0 Timestamp('2013-01-02 00:00:00') 1.0 3 'test' 'foo']
#  [1.0 Timestamp('2013-01-02 00:00:00') 1.0 3 'train' 'foo']
#  [1.0 Timestamp('2013-01-02 00:00:00') 1.0 3 'test' 'foo']
#  [1.0 Timestamp('2013-01-02 00:00:00') 1.0 3 'train' 'foo']]
#                    A         B         C         D
# 2013-01-01  0.231297  0.712790 -0.814281 -1.027549
# 2013-01-02  0.692430 -2.029240 -1.029616 -0.128162
# 2013-01-03  0.794290  1.833174  0.090310 -0.504759
# 2013-01-04 -0.236760  1.369424  0.783792 -1.045383
# 2013-01-05  0.171231 -0.245067 -0.540469 -0.743894
# -------------------------------------------------
#                    A         B         C         D
# 2013-01-04 -0.236760  1.369424  0.783792 -1.045383
# 2013-01-05  0.171231 -0.245067 -0.540469 -0.743894
# 2013-01-06  0.060644 -1.325892  0.118875 -0.639578
# -------------------------------------------------
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')
# -------------------------------------------------
# Index(['A', 'B', 'C', 'D'], dtype='object')
# -------------------------------------------------
# [[ 0.23129664  0.71279016 -0.81428057 -1.02754861]
#  [ 0.69243022 -2.02923966 -1.02961627 -0.12816242]
#  [ 0.79428976  1.83317353  0.09031039 -0.50475948]
#  [-0.23675969  1.36942437  0.78379175 -1.04538335]
#  [ 0.1712314  -0.24506715 -0.54046893 -0.74389406]
#  [ 0.06064397 -1.32589204  0.11887499 -0.63957839]]
# -------------------------------------------------
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.285522  0.052532 -0.231898 -0.681554
# std    0.390838  1.527300  0.682528  0.345031
# min   -0.236760 -2.029240 -1.029616 -1.045383
# 25%    0.088291 -1.055686 -0.745828 -0.956635
# 50%    0.201264  0.233862 -0.225079 -0.691736
# 75%    0.577147  1.205266  0.111734 -0.538464
# max    0.794290  1.833174  0.783792 -0.128162
# -------------------------------------------------
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.231297    0.692430    0.794290   -0.236760    0.171231    0.060644
# B    0.712790   -2.029240    1.833174    1.369424   -0.245067   -1.325892
# C   -0.814281   -1.029616    0.090310    0.783792   -0.540469    0.118875
# D   -1.027549   -0.128162   -0.504759   -1.045383   -0.743894   -0.639578
# -------------------------------------------------
#                    D         C         B         A
# 2013-01-01 -1.027549 -0.814281  0.712790  0.231297
# 2013-01-02 -0.128162 -1.029616 -2.029240  0.692430
# 2013-01-03 -0.504759  0.090310  1.833174  0.794290
# 2013-01-04 -1.045383  0.783792  1.369424 -0.236760
# 2013-01-05 -0.743894 -0.540469 -0.245067  0.171231
# 2013-01-06 -0.639578  0.118875 -1.325892  0.060644
# -------------------------------------------------
#                    A         B         C         D
# 2013-01-02  0.692430 -2.029240 -1.029616 -0.128162
# 2013-01-06  0.060644 -1.325892  0.118875 -0.639578
# 2013-01-05  0.171231 -0.245067 -0.540469 -0.743894
# 2013-01-01  0.231297  0.712790 -0.814281 -1.027549
# 2013-01-04 -0.236760  1.369424  0.783792 -1.045383
# 2013-01-03  0.794290  1.833174  0.090310 -0.504759
# -------------------------------------------------
# 2013-01-01    0.231297
# 2013-01-02    0.692430
# 2013-01-03    0.794290
# 2013-01-04   -0.236760
# 2013-01-05    0.171231
# 2013-01-06    0.060644
# Freq: D, Name: A, dtype: float64
# -------------------------------------------------
#                    A         B         C         D
# 2013-01-01  0.231297  0.712790 -0.814281 -1.027549
# 2013-01-02  0.692430 -2.029240 -1.029616 -0.128162
# 2013-01-03  0.794290  1.833174  0.090310 -0.504759
# -------------------------------------------------
#                   A         B         C         D
# 2013-01-02  0.69243 -2.029240 -1.029616 -0.128162
# 2013-01-03  0.79429  1.833174  0.090310 -0.504759
# 2013-01-04 -0.23676  1.369424  0.783792 -1.045383
# -------------------------------------------------
# A    0.231297
# B    0.712790
# C   -0.814281
# D   -1.027549
# Name: 2013-01-01 00:00:00, dtype: float64
# -------------------------------------------------
#                    A         B
# 2013-01-01  0.231297  0.712790
# 2013-01-02  0.692430 -2.029240
# 2013-01-03  0.794290  1.833174
# 2013-01-04 -0.236760  1.369424
# 2013-01-05  0.171231 -0.245067
# 2013-01-06  0.060644 -1.325892
# -------------------------------------------------
#                   A         B
# 2013-01-02  0.69243 -2.029240
# 2013-01-03  0.79429  1.833174
# 2013-01-04 -0.23676  1.369424
# -------------------------------------------------
# 0.23129664442354167
# -------------------------------------------------
# 0.23129664442354167
# -------------------------------------------------
# A   -0.236760
# B    1.369424
# C    0.783792
# D   -1.045383
# Name: 2013-01-04 00:00:00, dtype: float64
# -------------------------------------------------
#                    A         B
# 2013-01-04 -0.236760  1.369424
# 2013-01-05  0.171231 -0.245067
# -------------------------------------------------
#                    A         C
# 2013-01-02  0.692430 -1.029616
# 2013-01-03  0.794290  0.090310
# 2013-01-05  0.171231 -0.540469
# -------------------------------------------------
#                   A         B         C         D
# 2013-01-02  0.69243 -2.029240 -1.029616 -0.128162
# 2013-01-03  0.79429  1.833174  0.090310 -0.504759
# -------------------------------------------------
#                    B         C
# 2013-01-01  0.712790 -0.814281
# 2013-01-02 -2.029240 -1.029616
# 2013-01-03  1.833174  0.090310
# 2013-01-04  1.369424  0.783792
# 2013-01-05 -0.245067 -0.540469
# 2013-01-06 -1.325892  0.118875
# -------------------------------------------------
# -2.0292396648277617
# -------------------------------------------------
# -2.0292396648277617
# -------------------------------------------------
#                    A         B         C         D
# 2013-01-01  0.231297  0.712790 -0.814281 -1.027549
# 2013-01-02  0.692430 -2.029240 -1.029616 -0.128162
# 2013-01-03  0.794290  1.833174  0.090310 -0.504759
# 2013-01-05  0.171231 -0.245067 -0.540469 -0.743894
# 2013-01-06  0.060644 -1.325892  0.118875 -0.639578
# -------------------------------------------------
#                    A         B         C   D
# 2013-01-01  0.231297  0.712790       NaN NaN
# 2013-01-02  0.692430       NaN       NaN NaN
# 2013-01-03  0.794290  1.833174  0.090310 NaN
# 2013-01-04       NaN  1.369424  0.783792 NaN
# 2013-01-05  0.171231       NaN       NaN NaN
# 2013-01-06  0.060644       NaN  0.118875 NaN
# -------------------------------------------------
#                    A         B         C         D      E
# 2013-01-01  0.231297  0.712790 -0.814281 -1.027549    one
# 2013-01-02  0.692430 -2.029240 -1.029616 -0.128162    one
# 2013-01-03  0.794290  1.833174  0.090310 -0.504759    two
# 2013-01-04 -0.236760  1.369424  0.783792 -1.045383  three
# 2013-01-05  0.171231 -0.245067 -0.540469 -0.743894   four
# 2013-01-06  0.060644 -1.325892  0.118875 -0.639578  three
# -------------------------------------------------
#                    A         B         C         D     E
# 2013-01-03  0.794290  1.833174  0.090310 -0.504759   two
# 2013-01-05  0.171231 -0.245067 -0.540469 -0.743894  four
# -------------------------------------------------
# -------------------------------------------------
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64
# -------------------------------------------------
# -------------------------------------------------
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000 -0.814281  5.0  NaN
# 2013-01-02  0.692430 -2.029240 -1.029616  5.0  1.0
# 2013-01-03  0.794290  1.833174  0.090310  5.0  2.0
# 2013-01-04 -0.236760  1.369424  0.783792  5.0  3.0
# 2013-01-05  0.171231 -0.245067 -0.540469  5.0  4.0
# 2013-01-06  0.060644 -1.325892  0.118875  5.0  5.0
# -------------------------------------------------
# -------------------------------------------------
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000 -0.814281 -5.0  NaN
# 2013-01-02 -0.692430 -2.029240 -1.029616 -5.0 -1.0
# 2013-01-03 -0.794290 -1.833174 -0.090310 -5.0 -2.0
# 2013-01-04 -0.236760 -1.369424 -0.783792 -5.0 -3.0
# 2013-01-05 -0.171231 -0.245067 -0.540469 -5.0 -4.0
# 2013-01-06 -0.060644 -1.325892 -0.118875 -5.0 -5.0
# -------------------------------------------------
# -------------------------------------------------
#                   A         B         C    D    F    E
# 2013-01-01  0.00000  0.000000 -0.814281  5.0  NaN  1.0
# 2013-01-02  0.69243 -2.029240 -1.029616  5.0  1.0  1.0
# 2013-01-03  0.79429  1.833174  0.090310  5.0  2.0  NaN
# 2013-01-04 -0.23676  1.369424  0.783792  5.0  3.0  NaN
# -------------------------------------------------
#                   A        B         C    D    F    E
# 2013-01-02  0.69243 -2.02924 -1.029616  5.0  1.0  1.0
# -------------------------------------------------
#                   A         B         C    D    F    E
# 2013-01-01  0.00000  0.000000 -0.814281  5.0  5.0  1.0
# 2013-01-02  0.69243 -2.029240 -1.029616  5.0  1.0  1.0
# 2013-01-03  0.79429  1.833174  0.090310  5.0  2.0  5.0
# 2013-01-04 -0.23676  1.369424  0.783792  5.0  3.0  5.0
# -------------------------------------------------
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True
# -------------------------------------------------
# A    0.246973
# B   -0.066267
# C   -0.231898
# D    5.000000
# F    3.000000
# dtype: float64
# -------------------------------------------------
# 2013-01-01    1.046430
# 2013-01-02    0.726715
# 2013-01-03    1.943555
# 2013-01-04    1.983291
# 2013-01-05    1.677139
# 2013-01-06    1.770725
# Freq: D, dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64
# -------------------------------------------------
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -0.205710  0.833174 -0.909690  4.0  1.0
# 2013-01-04 -3.236760 -1.630576 -2.216208  2.0  0.0
# 2013-01-05 -4.828769 -5.245067 -5.540469  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN
# -------------------------------------------------
# A     1.383047
# B    -0.371094
# C    -1.298629
# D    28.000000
# F    16.800000
# dtype: float64
# -------------------------------------------------
#                     A           B           C      D      F
# 2013-01-01   0.000000    0.000000  -82.405194  506.0    NaN
# 2013-01-02  70.073938 -205.359054 -104.197167  506.0  101.2
# 2013-01-03  80.382124  185.517161    9.139411  506.0  202.4
# 2013-01-04 -23.960080  138.585746   79.319726  506.0  303.6
# 2013-01-05  17.328617  -24.800796  -54.695455  506.0  404.8
# 2013-01-06   6.137170 -134.180274   12.030149  506.0  506.0
# -------------------------------------------------
# -------------------------------------------------
# 0    2
# 1    0
# 2    0
# 3    2
# 4    4
# 5    6
# 6    4
# 7    4
# 8    1
# 9    3
# dtype: int64
# -------------------------------------------------
# 4    3
# 2    2
# 0    2
# 6    1
# 1    1
# 3    1
# Name: count, dtype: int64
# -------------------------------------------------
# -------------------------------------------------
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object
# -------------------------------------------------
# -------------------------------------------------
#           0         1         2         3
# 0  1.118987 -0.751355 -0.063243 -0.286853
# 1 -0.272054  1.454688  0.401573  0.570246
# 2  1.259506 -0.725486 -0.405925  0.101407
# 3  0.400354 -0.489508 -1.150111 -0.013246
# 4 -0.417878 -1.198373  1.747645 -0.262820
# 5  0.492250 -0.738782 -0.291195  0.499557
# 6 -0.519847 -0.020679 -0.468983  0.871411
# 7  0.729707  0.630942 -0.626648  0.945808
# 8  0.016468  1.309734  0.642137  0.838509
# 9 -0.053623  0.272591 -2.165823 -1.649044
# -------------------------------------------------
# -------------------------------------------------
#           0         1         2         3
# 0  1.118987 -0.751355 -0.063243 -0.286853
# 1 -0.272054  1.454688  0.401573  0.570246
# 2  1.259506 -0.725486 -0.405925  0.101407
# 3  0.400354 -0.489508 -1.150111 -0.013246
# 4 -0.417878 -1.198373  1.747645 -0.262820
# 5  0.492250 -0.738782 -0.291195  0.499557
# 6 -0.519847 -0.020679 -0.468983  0.871411
# 7  0.729707  0.630942 -0.626648  0.945808
# 8  0.016468  1.309734  0.642137  0.838509
# 9 -0.053623  0.272591 -2.165823 -1.649044
# -------------------------------------------------
# -------------------------------------------------
#    key  lval
# 0  foo     1
# 1  foo     2
# -------------------------------------------------
#    key  rval
# 0  foo     4
# 1  foo     5
# -------------------------------------------------
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5
# -------------------------------------------------
# -------------------------------------------------
#    key  lval
# 0  foo     1
# 1  bar     2
# -------------------------------------------------
#    key  rval
# 0  foo     4
# 1  bar     5
# -------------------------------------------------
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5
# -------------------------------------------------
# -------------------------------------------------
#      A      B         C         D
# 0  foo    one -0.662940 -0.535029
# 1  bar    one  0.768330  0.081011
# 2  foo    two  0.070166 -0.985266
# 3  bar  three -1.847479  0.773038
# 4  foo    two -1.041940 -0.660021
# 5  bar    two  0.444808 -0.331022
# 6  foo    one -0.610483 -0.308151
# 7  foo  three  0.761224  0.745893
# -------------------------------------------------
#             C         D
# A
# bar -0.634342  0.523027
# foo -1.483973 -1.742574
# -------------------------------------------------
#                   C         D
# A   B
# bar one    0.768330  0.081011
#     three -1.847479  0.773038
#     two    0.444808 -0.331022
# foo one   -1.273423 -0.843180
#     three  0.761224  0.745893
#     two   -0.971774 -1.645287
# -------------------------------------------------
# -------------------------------------------------
#                      A         B
# first second
# bar   one     1.079580 -1.025362
#       two     1.125659 -0.318513
# baz   one    -0.442630  0.144367
#       two    -1.281315  2.800537
# -------------------------------------------------
# -------------------------------------------------
#         A  B    C         D         E
# 0     one  A  foo -0.736058 -2.094691
# 1     one  B  foo -0.210294 -2.125987
# 2     two  C  foo -0.388521 -1.231892
# 3   three  A  bar  1.436698  0.570190
# 4     one  B  bar  0.046639  0.493066
# 5     one  C  bar  1.722052  0.988741
# 6     two  A  foo -0.103788 -0.522686
# 7   three  B  foo  0.693576 -0.443969
# 8     one  C  foo -0.226052  0.006009
# 9     one  A  bar  0.245611  0.278034
# 10    two  B  bar -0.162115  0.873144
# 11  three  C  bar -0.241988 -0.666287
# -------------------------------------------------
# C             bar       foo
# A     B
# one   A  0.245611 -0.736058
#       B  0.046639 -0.210294
#       C  1.722052 -0.226052
# three A  1.436698       NaN
#       B       NaN  0.693576
#       C -0.241988       NaN
# two   A       NaN -0.103788
#       B -0.162115       NaN
#       C       NaN -0.388521
# -------------------------------------------------
# -------------------------------------------------
# 2012-01-01    26538
# Freq: 5T, dtype: int64
# -------------------------------------------------
# -------------------------------------------------
# 2012-03-06   -0.266508
# 2012-03-07   -0.579174
# 2012-03-08   -1.134016
# 2012-03-09   -1.366108
# 2012-03-10   -1.601267
# Freq: D, dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# 2012-03-06 00:00:00+00:00   -0.266508
# 2012-03-07 00:00:00+00:00   -0.579174
# 2012-03-08 00:00:00+00:00   -1.134016
# 2012-03-09 00:00:00+00:00   -1.366108
# 2012-03-10 00:00:00+00:00   -1.601267
# Freq: D, dtype: float64
# -------------------------------------------------
# 2012-03-05 19:00:00-05:00   -0.266508
# 2012-03-06 19:00:00-05:00   -0.579174
# 2012-03-07 19:00:00-05:00   -1.134016
# 2012-03-08 19:00:00-05:00   -1.366108
# 2012-03-09 19:00:00-05:00   -1.601267
# Freq: D, dtype: float64
# -------------------------------------------------
# DatetimeIndex(['2012-03-06', '2012-03-07', '2012-03-08', '2012-03-09',
#                '2012-03-10'],
#               dtype='datetime64[ns]', freq='D')
# -------------------------------------------------
# DatetimeIndex(['2012-03-13', '2012-03-14', '2012-03-15', '2012-03-16',
#                '2012-03-16'],
#               dtype='datetime64[ns]', freq=None)
# -------------------------------------------------
# -------------------------------------------------
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']
# -------------------------------------------------
# -------------------------------------------------
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): ['very bad', 'bad', 'medium', 'good', 'very good']
# -------------------------------------------------
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good
# -------------------------------------------------
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64
# -------------------------------------------------
# -------------------------------------------------
#    Unnamed: 0  0  1  2  3  4
# 0           0  3  4  0  1  0
# 1           1  3  4  4  0  2
# 2           2  3  4  2  3  4
# 3           3  3  2  0  1  0
# 4           4  0  2  1  2  4
# 5           5  0  4  4  3  3
# 6           6  4  1  0  1  3
# 7           7  2  4  4  3  1
# 8           8  4  3  4  3  1
# 9           9  2  4  3  3  1
# -------------------------------------------------
# -------------------------------------------------
#    0  1  2  3  4
# 0  3  4  0  1  0
# 1  3  4  4  0  2
# 2  3  4  2  3  4
# 3  3  2  0  1  0
# 4  0  2  1  2  4
# 5  0  4  4  3  3
# 6  4  1  0  1  3
# 7  2  4  4  3  1
# 8  4  3  4  3  1
# 9  2  4  3  3  1
# -------------------------------------------------
#    Unnamed: 0  0  1  2  3  4
# 0           0  3  4  0  1  0
# 1           1  3  4  4  0  2
# 2           2  3  4  2  3  4
# 3           3  3  2  0  1  0
# 4           4  0  2  1  2  4
# 5           5  0  4  4  3  3
# 6           6  4  1  0  1  3
# 7           7  2  4  4  3  1
# 8           8  4  3  4  3  1
# 9           9  2  4  3  3  1
# -------------------------------------------------
